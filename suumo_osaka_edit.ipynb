# %%
import pandas as pd
import numpy as np

# %%
osaka = pd.read_csv('suumo_kanjosen_toho5min_chikunenn10years.csv')

# %%
osaka.head()
# Out:
#         路線  最寄駅  駅までの所要時間（分）  家賃（万円） 間取り   占有面積
# 0  ＪＲ大阪環状線   今宮            5    5.30  1K  23.80
# 1  地下鉄御堂筋線  大国町            8    5.80  1K  21.77
# 2  ＪＲ大阪環状線  天王寺            5    5.75  1K  21.74
# 3  ＪＲ大阪環状線   玉造            4    6.06  1K  23.34
# 4  ＪＲ大阪環状線   福島            5    7.20  1K  25.16

# %%
kanjoline = osaka[osaka['路線']=='ＪＲ大阪環状線']
kanjoline
# Out:
#           路線  最寄駅  駅までの所要時間（分）  家賃（万円）    間取り   占有面積
# 0    ＪＲ大阪環状線   今宮            5    5.30     1K  23.80
# 2    ＪＲ大阪環状線  天王寺            5    5.75     1K  21.74
# 3    ＪＲ大阪環状線   玉造            4    6.06     1K  23.34
# 4    ＪＲ大阪環状線   福島            5    7.20     1K  25.16
# 6    ＪＲ大阪環状線   玉造            5   14.00   1LDK  50.01
# ..       ...  ...          ...     ...    ...    ...
# 982  ＪＲ大阪環状線   京橋            5    6.90     1K  25.11
# 984  ＪＲ大阪環状線   京橋            4    6.28     1K  22.80
# 985  ＪＲ大阪環状線   京橋            2    6.90     2K  25.37
# 987  ＪＲ大阪環状線   京橋            5   10.50   1LDK  36.95
# 989  ＪＲ大阪環状線   京橋            5    5.30  ワンルーム  18.75
#
# [656 rows x 6 columns]

# %%
kanjoline['駅までの距離（m）'] = kanjoline['駅までの所要時間（分）']*80
kanjoline
# Out:
# /var/folders/g5/k4p940jx1wd52k96v3hxn1940000gn/T/ipykernel_77572/2301197271.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kanjoline['駅までの距離（m）'] = kanjoline['駅までの所要時間（分）']*80
#           路線  最寄駅  駅までの所要時間（分）  家賃（万円）    間取り   占有面積  駅までの距離（m）
# 0    ＪＲ大阪環状線   今宮            5    5.30     1K  23.80        400
# 2    ＪＲ大阪環状線  天王寺            5    5.75     1K  21.74        400
# 3    ＪＲ大阪環状線   玉造            4    6.06     1K  23.34        320
# 4    ＪＲ大阪環状線   福島            5    7.20     1K  25.16        400
# 6    ＪＲ大阪環状線   玉造            5   14.00   1LDK  50.01        400
# ..       ...  ...          ...     ...    ...    ...        ...
# 982  ＪＲ大阪環状線   京橋            5    6.90     1K  25.11        400
# ...

# %%
kanjoline.isnull()
# Out:
#         路線    最寄駅  駅までの所要時間（分）  家賃（万円）    間取り   占有面積  駅までの距離（m）
# 0    False  False        False   False  False  False      False
# 2    False  False        False   False  False  False      False
# 3    False  False        False   False  False  False      False
# 4    False  False        False   False  False  False      False
# 6    False  False        False   False  False  False      False
# ..     ...    ...          ...     ...    ...    ...        ...
# 982  False  False        False   False  False  False      False
# 984  False  False        False   False  False  False      False
# 985  False  False        False   False  False  False      False
# 987  False  False        False   False  False  False      False
# 989  False  False        False   False  False  False      False
#
# [656 rows x 7 columns]

# %%
kanjoline.describe()
# Out:
#        駅までの所要時間（分）      家賃（万円）        占有面積   駅までの距離（m）
# count   656.000000  656.000000  656.000000  656.000000
# mean      3.954268    7.269634   28.226890  316.341463
# std       1.370701    2.627612    9.882298  109.656086
# min       1.000000    4.700000   18.000000   80.000000
# 25%       3.000000    5.900000   22.967500  240.000000
# 50%       4.000000    6.300000   24.920000  320.000000
# 75%       5.000000    7.500000   29.825000  400.000000
# max      10.000000   24.600000   99.370000  800.000000

# %%
kanjoline.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 656 entries, 0 to 989
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   路線           656 non-null    object
#  1   最寄駅          656 non-null    object
#  2   駅までの所要時間（分）  656 non-null    int64
#  3   家賃（万円）       656 non-null    float64
#  4   間取り          656 non-null    object
#  5   占有面積         656 non-null    float64
#  6   駅までの距離（m）    656 non-null    int64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 41.0+ KB

# %%
kanjoline[kanjoline['最寄駅']=='福島'].sort_values(by='家賃（万円）')
# Out:
#           路線 最寄駅  駅までの所要時間（分）  家賃（万円）    間取り   占有面積  駅までの距離（m）
# 759  ＪＲ大阪環状線  福島            5    5.95     1K  21.46        400
# 837  ＪＲ大阪環状線  福島            5    6.65     1K  23.24        400
# 767  ＪＲ大阪環状線  福島            5    6.65     1K  23.24        400
# 772  ＪＲ大阪環状線  福島            5    6.80  ワンルーム  24.93        400
# 427  ＪＲ大阪環状線  福島            5    6.80     1K  24.93        400
# 500  ＪＲ大阪環状線  福島            4    6.80     1K  23.44        320
# 430  ＪＲ大阪環状線  福島            5    6.85     1K  23.00        400
# 928  ＪＲ大阪環状線  福島            5    6.90    1SK  30.85        400
# 4    ＪＲ大阪環状線  福島            5    7.20     1K  25.16        400
# 783  ＪＲ大阪環状線  福島            4    7.50     1K  20.58        320
# 442  ＪＲ大阪環状線  福島            3    7.60     1K  24.36        240
# 786  ＪＲ大阪環状線  福島            3    7.60     1K  24.36        240
# 231  ＪＲ大阪環状線  福島            5    7.90     1K  25.52        400
# 777  ＪＲ大阪環状線  福島            5    7.90     1K  27.22        400
# ...

# %%
kanjoline[kanjoline['最寄駅']=='天満'].sort_values(by='占有面積',ascending=False)
# Out:
#           路線 最寄駅  駅までの所要時間（分）  家賃（万円）    間取り   占有面積  駅までの距離（m）
# 659  ＪＲ大阪環状線  天満            4    9.80  ワンルーム  43.50        320
# 381  ＪＲ大阪環状線  天満            5   13.50   1LDK  42.68        400
# 718  ＪＲ大阪環状線  天満            5   12.05   1LDK  41.40        400
# 18   ＪＲ大阪環状線  天満            5   13.70    1DK  40.51        400
# 137  ＪＲ大阪環状線  天満            5   13.70    1DK  40.51        400
# 921  ＪＲ大阪環状線  天満            5    9.40   1LDK  35.43        400
# 644  ＪＲ大阪環状線  天満            5   10.00   1LDK  35.17        400
# 735  ＪＲ大阪環状線  天満            5    8.20    1DK  31.50        400
# 946  ＪＲ大阪環状線  天満            5    8.20    1DK  31.50        400
# 673  ＪＲ大阪環状線  天満            1    8.20   1LDK  31.43         80
# 972  ＪＲ大阪環状線  天満            2    8.30     1K  29.49        160
# 109  ＪＲ大阪環状線  天満            3    8.30   1LDK  29.49        240
# 672  ＪＲ大阪環状線  天満            5    8.80    1DK  28.84        400
# 342  ＪＲ大阪環状線  天満            5    8.80    1DK  28.84        400
# ...
