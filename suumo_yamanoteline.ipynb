# %%
import requests
from bs4 import BeautifulSoup
import re

# %%
url = 'https://suumo.jp/tokyo/en_yamanotesen/'
res = requests.get(url)

# %%
res
# Out:
# <Response [200]>

# %%
res.text
# Out:
# '<!DOCTYPE html>\r\n<!--[if lt IE 7]><html lang="ja" class="ie"><![endif]-->\r\n<!--[if IE 7]><html lang="ja" class="ie"><![endif]-->\r\n<!--[if IE 8]><html lang="ja" class="ie"><![endif]-->\r\n<!--[if gt IE 8]><!-->\r\n<html lang="ja" class="is-jsOff">\r\n<!--<![endif]-->\r\n<!-- JJ901FC0040 START -->\r\n<head>\r\n<meta charset="utf-8" />\r\n<script>document.documentElement.className="is-jsOn"</script>\r\n<!-- JJ901FI0110 -->\r\n<title>【SUUMO】ＪＲ山手線(東京都)の不動産情報・住宅情報</title>\r\n<meta name="keywords" content=\'ＪＲ山手線,不動産,住宅,住宅情報,不動産情報,不動産賃貸,売買,購入,物件,検索,SUUMO,スーモ\' />\r\n<meta name="description" content=\'【SUUMO(スーモ)】ＪＲ山手線の不動産・住宅に関する物件検索結果一覧です。ＪＲ山手線の賃貸情報からマンション・一戸建て・土地などの不動産売買・物件購入情報はもちろん、注文住宅、リフォーム、設備情報に至るまでの豊富な住宅情報で、あなたの幸せな住まい探しをサポートします。\' />\r\n<link rel="shortcut icon" href="/front/img/favicon.ico" type="image/vnd.microsoft.icon" />\r\n<link rel="icon" href="/front/img/favicon.ico" type="image/vnd.microsoft.icon" />\r\n<meta name="robots" content="noarchive">\r\n<!-- JJ901FI0110 -->\r\n<link rel="stylesheet" href="/edit/assets/suumo/css/ou-list.css?1670549607000" media="screen" type="text/css" />\r\n<!--[if lt IE 9]>\r\n<script src="/edit/assets/allsites/js/html5.js?1501566649000"></script>\r\n<![endif]-->\r\n<!-- GTMタグ用↓ -->\r\n<script type="text/javascript">\r\nvar gapSuumoPcForIchiran = [{\n\tkamin : "",\n\tkamax : "",\n\tchinryomin : "",\n\tchinryomax : "",\n\tm : [""],\n\tmenmin : "",\n\tmenmax : "",\n\tnyukyo : "",\n\tse : [""],\n\tsenm : [""],\n\tnewupdflg : "",\n\tnewupd3flg : "",\n\tnewupd7flg : "",\n\tnewupd2_7flg : "",\n\tnewflg : "0",\n\ttanm : "",\n\tscnm : [""],\n\tkibo : "",\n\tet : "",\n\tbf : "",\n\ttmenmin : "",\n\ttmenmax : "",\n\tsa : [""],\n\tsc : [""],\n\tta : "",\n\ts : [""],\n\te : [""],\n\tkm : "",\n\tcn : "",\n\tareacd : "030",\n\tareanm : "関東",\n\tsckukuri1 : "",\n\tsckukuri1nm : "",\n\tsckukuri3 : [""],\n\tsckukuri3nm : [""],\n\tgamen_type : "10"\n}];\r\n//-->\r\n</script>\r\n<!-- GTMタグ用↑ -->\r\n<!-- PageNation01 Start -->\r\n<link rel="next" href="https://suumo.jp/tokyo/en_yamanotesen/pnz12.html" /><!-- PageNation01 End -->\r\n</head>\r\n<body>\r\n<form id="js-kensakuJoukenTourokuForm" action="https://suumo.jp/jj/common/service/JJ901FM308/" target = "_blank">\r\n\t\t<input type="hidden" name="tbi4dbs" value="">\r\n\t\t<input type="hidden" name="searchdisp" value="ＪＲ山手線" />\r\n\t\t<input type="hidden" name="actionpath" value="/common/ichiran/JJ901FC004/" />\r\n\t\t<input type="hidden" name="ra" value="030013" />\r\n\t\t<input type="hidden" name="rn" value="0005" />\r\n\t\t<input type="hidden" name="ar" value="030" />\r\n\t\t</form>\r\n\t<!-- GlobalHeader01_01 Start -->\r\n<link rel="stylesheet" href="/edit/assets/suumo/css/header-gnav.css?1550193296000" media="screen" />\r\n<form name="common_common_JJ901FK101ActionForm" id="js-turnbackPostForm" method="post" action="https://suumo.jp/jj/common/common/JJ901FK101/showLogin/"><input type="hidden" name="tbi4dbs" value="">\r\n</form><form id="js-myKensakuJokenForm" method="post" action="/jj/common/service/JJ901FM303/">\r\n\t<input type="hidden" name="ar" value="030">\r\n\t</form>\r\n<form id="js-popLatestBukkenForm" method="post" action="/jj/common/parts/JJ901FI306/">\r\n\t<input type="hidden" name="ar" value="">\r\n\t<input type="hidden" name="bs" value="">\r\n\t< ...

# %%
soup = BeautifulSoup(res.text, "html.parser")

# %% [markdown]
# # findメソッドで情報抽出

# %% [markdown]
# # １件目の情報

# %%
bukkens = soup.find_all('li',attrs={'class':'cassette js-bukkenCassette'})
bukken = bukkens[0]
bukken.prettify
# Out:
# <bound method Tag.prettify of <li class="cassette js-bukkenCassette">
# <div class="cassette-cbx">
# <div class="ui-sprite--mark_check" style="display:none">チェック</div>
# <input class="js-ikkatsuCB" id="bukken_0" type="hidden" value="100315340691">
# <label class="cbx_list" for="bukken_0"> </label>
# <input class="js-shiryoukey" type="hidden" value="FR_040_100315340691">
# <input class="js-clipkey" type="hidden" value="100315340691">
# </input></input></input></div>
# <div class="cassettebox js-normalLink js-cassetLink">
# <div class="cassettebox-header">
# <span class="ui-pct ui-pct--util1 cassettebox-hpct cassettebox-hpctcat">
# 								賃貸</span>
# <span class="ui-label ui-label--cta1 cassettebox-hpct">Today's新着</span>
# <h2 class="cassettebox-title">
# <a class="js-cassetLinkHref" href="/chintai/bc_100315340691/">2.9万円　東京メトロ千代田線/根津</a></h2>
# </div>
# <div class="cassettebox-body">
# <div class="ui-media">
# <div class="infodatabox">
# <div class="ui-media-object infodatabox-object">
# <a href="/chintai/bc_100315340691/"><img class="js-noContextMenu js-scrollLazy js-adjustImg" height="0" rel="https://img01.suumo.com/front/gazo/fr/bukken/691/100315340691/100315340691_gt.jpg" src="...%3D%3D" width="0"/></a></div>
# <div class="ui-media-body">
# <p class="infodatabox-lead">
# 										シェアハウス♪敷金礼金なしで初期費用抑えられます♪</p>
# <div class="infodatabox-boxgroup">
# <div class="infodatabox-box">
# <table class="listtable">
# <tbody>
# <tr>
# <th>
# <div class="infodatabox-box-title">住所</div>
# </th>
# <th>
# <div class="infodatabox-box-title">沿線・駅</div>
# </th>
# <th>
# <div class="infodatabox-box-title">バス/徒歩</div>
# </th>
# </tr>
# <tr>
# <td>
# <div class="infodatabox-box-txt">
# 																東京都台東区池之端４</div>
# </td>
# <td>
# <div class="infodatabox-box-txt">東京メトロ千代田線/根津</div>
# </td>
# <td>
# <div class="infodatabox-box-txt">―<br/>徒歩7分</div>
# </td>
# </tr>
# </tbody>
# </table>
# </div>
# <div class="infodatabox-box">
# <table class="listtable">
# <tbody>
# <tr>
# <th>
# <div class="infodatabox-box-title">価格（月額のローン支払い）<a href="/edit/yogo/getsugaku.html" target="_blank"><span class="ui-icon--cherry js-noCassetteLink"></span></a></div>
# </th>
# <th>
# <div class="infodatabox-box-title">間取り/面積/総戸数</div>
# </th>
# <th>
# <div class="infodatabox-box-title">築年数・入居時期</div>
# </th>
# </tr>
# <tr>
# <td>
# <div class="infodatabox-box-txt">
# <dl class="infodatabox-details">
# <dt class="infodatabox-details-title">賃料：</dt>
# <dd class="infodatabox-details-txt">2.9万円</dd>
# </dl>
# <dl class="infodatabox-details">
# <dt class="infodatabox-details-title">管理・共益費：</dt>
# <dd class="infodatabox-details-txt">11000円</dd>
# </dl>
# <dl class="infodatabox-details">
# <dt class="infodatabox-details-title">礼金/敷金：</dt>
# <dd class="infodatabox-details-txt">-/-</dd>
# </dl>
# </div>
# </td>
# <td>
# <div class="infodatabox-box-txt">
# <dl class="infodatabox-details">
# <dt class="infodatabox-details-title">専有面積：</dt>
# <dd class="infodatabox-details-txt">
# 																			4.86m<sup>2</sup></dd>
# </dl>
# <dl class="infodatabox-details">
# <dt class="infodatabox-details-title">間取り：</dt>
# <dd class="infodatabox-details-txt">
# 																			ワンルーム</dd>
# </dl>
# </div>
# </td>
# <td>
# <div class="infodatabox-box-txt">
# 																築53年</div>
# </td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="cassettebox-action">
# <ul class="ui-list--hz">
# <li>
# <a class="ui-btn ui-btn--util1 listbtn" href="/chintai/bc_100315340691/">詳細表示する</a></li>
# <li><a class="ui-sprite--actionbtn_addmylist js-addMyList js-linkSuppresser" href="javascript:void(0);">お気に入りに追加する</a></li>
# </ul>
# </div>
# </div>
# </div>
# </li>>

# %%
# 物件情報
bukken_info = bukken.select(".infodatabox-box-txt")
bukken_info
# Out:
# [<div class="infodatabox-box-txt">
#  																東京都台東区池之端４</div>,
#  <div class="infodatabox-box-txt">東京メトロ千代田線/根津</div>,
#  <div class="infodatabox-box-txt">―<br/>徒歩7分</div>,
#  <div class="infodatabox-box-txt">
#  <dl class="infodatabox-details">
#  <dt class="infodatabox-details-title">賃料：</dt>
#  <dd class="infodatabox-details-txt">2.9万円</dd>
#  </dl>
#  <dl class="infodatabox-details">
#  <dt class="infodatabox-details-title">管理・共益費：</dt>
#  <dd class="infodatabox-details-txt">11000円</dd>
#  </dl>
#  <dl class="infodatabox-details">
#  <dt class="infodatabox-details-title">礼金/敷金：</dt>
#  <dd class="infodatabox-details-txt">-/-</dd>
#  </dl>
#  </div>,
#  <div class="infodatabox-box-txt">
#  <dl class="infodatabox-details">
#  <dt class="infodatabox-details-title">専有面積：</dt>
#  <dd class="infodatabox-details-txt">
#  																			4.86m<sup>2</sup></dd>
#  </dl>
#  <dl class="infodatabox-details">
#  <dt class="infodatabox-details-title">間取り：</dt>
#  <dd class="infodatabox-details-txt">
#  																			ワンルーム</dd>
#  </dl>
#  </div>,
#  <div class="infodatabox-box-txt">
#  																築53年</div>]

# %%
# 最寄駅
railline = bukken_info[1].text.split('/')[0]
station = bukken_info[1].text.split('/')[1]

# %%
railline
# Out:
# '東京メトロ千代田線'

# %%
station
# Out:
# '根津'

# %%
# 駅までの距離
how_long = bukken_info[2].text
how_long = int(re.sub(r"\D", "", how_long) )
how_long
# Out:
# 7

# %%
# 家賃
rentprice = bukken.find('dd',attrs={'class':'infodatabox-details-txt'}).text
rentprice = float(rentprice.replace('万円',''))
rentprice
# Out:
# 2.9

# %%
# 占有面積
price = bukken.find_all('dd',attrs={'class':'infodatabox-details-txt'})
area = price[3].text
area = float(re.sub(r"[^\d.]", "", area) )
area
# Out:
# 4.862

# %%
# 間取り
room_type = price[4].text.replace('\r\n','').replace('\t','')
room_type
# Out:
# 'ワンルーム'

# %%
# １ページの全情報取得
data = []

url = 'https://suumo.jp/tokyo/en_yamanotesen/'
res = requests.get(url)
soup = BeautifulSoup(res.text,'html.parser')
bukkens = soup.find_all('li',attrs={'class':'cassette js-bukkenCassette'})

for bukken in bukkens:
    bukken_info = bukken.select(".infodatabox-box-txt")
    # 沿線
    railline = bukken_info[1].text.split('/')[0]
#     最寄駅
    station = bukken_info[1].text.split('/')[1]
    # 駅までの所要時間
    how_long = bukken_info[2].text
    how_long = int(re.sub(r"\D", "", how_long) )
    # 家賃
    rentprice = bukken.find('dd',attrs={'class':'infodatabox-details-txt'}).text
    rentprice = float(rentprice.replace('万円',''))
    # 占有面積
    price = bukken.find_all('dd',attrs={'class':'infodatabox-details-txt'})
    area = price[3].text
    area = float(re.sub(r"[^\d.]", "", area) )
    # 間取り
    room_type = price[4].text.replace('\r\n','').replace('\t','')

    datum = {}
    datum['沿線']=railline
    datum['最寄駅']=station
    datum['駅までの所要時間（分）']=how_long
    datum['家賃（万円）']=rentprice
    datum['占有面積']=area
    datum['間取り']=room_type
    data.append(datum)

# %%
data
# Out:
# [{'沿線': '東京メトロ千代田線',
#   '最寄駅': '根津',
#   '駅までの所要時間（分）': 7,
#   '家賃（万円）': 2.9,
#   '占有面積': 4.862,
#   '間取り': 'ワンルーム'},
#  {'沿線': 'ＪＲ中央線',
#   '最寄駅': '大久保',
#   '駅までの所要時間（分）': 3,
#   '家賃（万円）': 3.0,
#   '占有面積': 13.972,
#   '間取り': 'ワンルーム'},
#  {'沿線': 'ＪＲ山手線',
#   '最寄駅': '池袋',
#   '駅までの所要時間（分）': 7,
#   '家賃（万円）': 3.52,
#   '占有面積': 182.0,
#   '間取り': 'ワンルーム'},
#  {'沿線': 'ＪＲ常磐線',
#   '最寄駅': '三河島',
#   '駅までの所要時間（分）': 4,
#   '家賃（万円）': 3.8,
#   '占有面積': 82.0,
#   '間取り': 'ワンルーム'},
#  {'沿線': 'ＪＲ山手線',
#   '最寄駅': '大塚',
#   '駅までの所要時間（分）': 5,
#   '家賃（万円）': 3.85,
#   '占有面積': 19.462,
#   '間取り': '1DK'},
#  {'沿線': 'ＪＲ山手線',
#   '最寄駅': '恵比寿',
#   '駅までの所要時間（分）': 4,
#   '家賃（万円）': 3.9,
#   '占有面積': 1.942,
#   '間取り': 'ワンルーム'},
#  {'沿線': '東京メトロ南北線',
#   '最寄駅': '西ケ原',
#   '駅までの所要時間（分）': 9,
#   '家賃（万円）': 4.0,
#   '占有面積': 26.52,
#   '間取り': '2K'},
#  {'沿線': '東京メトロ南北線',
#   '最寄駅': '西ケ原',
#   '駅までの所要時間（分）': 9,
#   '家賃（万円）': 4.0,
#   '占有面積': 26.52,
#   '間取り': '2K'},
#  {'沿線': 'ＪＲ山手線',
#   '最寄駅': '秋葉原',
#   '駅までの所要時間（分）': 10,
#   '家賃（万円）': 4.1,
#   '占有面積': 7.132,
#   '間取り': 'ワンルーム'},
#  {'沿線': 'ＪＲ山手線',
#   '最寄駅': '御徒町',
#   '駅までの所要時間（分）': 3,
#   '家賃（万円）': 4.1,
#   '占有面積': 7.132,
#   '間取り': 'ワンルーム'},
#  {'沿線': 'ＪＲ山手線',
#   '最寄駅': '御徒町',
#   '駅までの所要時間（分）': 3,
#   '家賃（万円）': 4.1,
#   '占有面積': 7.132,
#   '間取り': 'ワンルーム'},
#  {'沿線': 'ＪＲ山手線',
#   '最寄駅': '御徒町',
#   '駅までの所要時間（分）': 3,
#   '家賃（万円）': 4.1,
#   '占有面積': 7.132,
#   '間取り': 'ワンルーム'},
#  {'沿線': 'ＪＲ山手線',
#   '最寄駅': '御徒町',
#   '駅までの所要時間（分）': 3,
#   '家賃（万円）': 4.1,
#   '占有面積': 7.132,
#   '間取り': 'ワンルーム'},
#  {'沿線': 'ＪＲ山手線',
#   '最寄駅': '御徒町',
#   '駅までの所要時間（分）': 3,
#   '家賃（万円）': 4.1,
#   '占有面積': 7.132,
#   '間取り': 'ワンルーム'},
#  {'沿線': 'ＪＲ山手線',
#   '最寄駅': '池袋',
#   '駅までの所要時間（分）': 17,
#   '家賃（万円）': 4.3,
#   '占有面積': 17.392,
#   '間取り': 'ワンルーム'},
#  {'沿線': 'ＪＲ埼京線',
#   '最寄駅': '南与野',
#   '駅までの所要時間（分）': 166,
#   '家賃（万円）': 4.3,
#   '占有面積': 19.872,
#   '間取り': '1K'},
#  {'沿線': 'ＪＲ京浜東北線',
#   '最寄駅': '蕨',
#   '駅までの所要時間（分）': 61,
#   '家賃（万円）': 4.4,
#   '占有面積': 19.872,
#   '間取り': '1K'},
#  {'沿線': 'ＪＲ常磐線',
#   '最寄駅': '三河島',
#   '駅までの所要時間（分）': 4,
#   '家賃（万円）': 4.5,
#   '占有面積': 82.0,
#   '間取り': 'ワンルーム'},
#  {'沿線': 'ＪＲ山手線',
#   '最寄駅': '田端',
#   '駅までの所要時間（分）': 17,
#   '家賃（万円）': 4.5,
#   '占有面積': 12.722,
#   '間取り': 'ワンルーム'},
#  {'沿線': 'ＪＲ山手線',
#   '最寄駅': '西日暮里',
#   '駅までの所要時間（分）': 11,
#   '家賃（万円）': 4.5,
#   '占有面積': 13.82,
#   '間取り': 'ワンルーム'},
#  {'沿線': 'ＪＲ山手線',
#   '最寄駅': '巣鴨',
#   '駅までの所要時間（分）': 7,
#   '家賃（万円）': 4.5,
#   '占有面積': 9.662,
#   '間取り': 'ワンルーム'},
#  {'沿線': 'ＪＲ武蔵野線',
#   '最寄駅': '西浦和',
#   '駅までの所要時間（分）': 14,
#   '家賃（万円）': 4.5,
#   '占有面積': 20.282,
#   '間取り': '1K'},
#  {'沿線': 'ＪＲ山手線',
#   '最寄駅': '駒込',
#   '駅までの所要時間（分）': 2,
#   '家賃（万円）': 4.6,
#   '占有面積': 142.0,
#   '間取り': 'ワンルーム'},
#  {'沿線': '東京メトロ東西線',
#   '最寄駅': '早稲田',
#   '駅までの所要時間（分）': 7,
#   '家賃（万円）': 4.6,
#   '占有面積': 14.582,
#   '間取り': 'ワンルーム'},
#  {'沿線': 'ＪＲ山手線',
#   '最寄駅': '西日暮里',
#   '駅までの所要時間（分）': 7,
#   '家賃（万円）': 4.6,
#   '占有面積': 14.912,
#   '間取り': 'ワンルーム'},
#  {'沿線': 'ＪＲ山手線',
#   '最寄駅': '大塚',
#   '駅までの所要時間（分）': 11,
#   '家賃（万円）': 4.7,
#   '占有面積': 12.422,
#   '間取り': 'ワンルーム'},
#  {'沿線': '日暮里・舎人ライナー',
#   '最寄駅': '赤土小学校前',
#   '駅までの所要時間（分）': 5,
#   '家賃（万円）': 4.7,
#   '占有面積': 12.722,
#   '間取り': 'ワンルーム'},
#  {'沿線': '東京メトロ丸ノ内線',
#   '最寄駅': '新大塚',
#   '駅までの所要時間（分）': 3,
#   '家賃（万円）': 4.7,
#   '占有面積': 12.422,
#   '間取り': 'ワンルーム'},
#  {'沿線': '東京メトロ丸ノ内線',
#   '最寄駅': '新大塚',
#   '駅までの所要時間（分）': 3,
#   '家賃（万円）': 4.7,
#   '占有面積': 12.422,
#   '間取り': 'ワンルーム'},
#  {'沿線': '東京メトロ丸ノ内線',
#   '最寄駅': '新大塚',
#   '駅までの所要時間（分）': 3,
#   '家賃（万円）': 4.7,
#   '占有面積': 12.422,
#   '間取り': 'ワンルーム'}]

# %%
body = soup.find("body")
pages = body.find_all("div", {'class':'pagination pagination_set-nav'})
pages_text = str(pages)
pages_split = pages_text.split('</a></li>\n</ol>')
num_pages = int(pages_split[0].split('>')[-1])
print("ページ数＝",num_pages)
# Out:
# ページ数＝ 7900

# %%
url = 'https://suumo.jp/jj/common/ichiran/JJ901FC004/?initFlg=1&seniFlg=1&pc=30&ar=030&ra=030013&rnTmp=0005&newflg=0&km=1&rn=0005&rnek=000514970'
res = requests.get(url)
soup = BeautifulSoup(res.text,'html.parser')

body = soup.find("body")
pages = body.find_all("div", {'class':'pagination pagination_set-nav'})
pages_text = str(pages)
pages_split = pages_text.split('</a></li>\n</ol>')
num_pages = int(pages_split[0].split('>')[-1])
num_pages
# Out:
# 531

# %%
# 全ページの情報取得
data = []

url = 'https://suumo.jp/jj/common/ichiran/JJ901FC004/?initFlg=1&seniFlg=1&pc=30&ar=030&ra=030013&rnTmp=0005&newflg=0&km=1&rn=0005&rnek=000514970'
res = requests.get(url)
soup = BeautifulSoup(res.text,'html.parser')

body = soup.find("body")
pages = body.find_all("div", {'class':'pagination pagination_set-nav'})
pages_text = str(pages)
pages_split = pages_text.split('</a></li>\n</ol>')
num_pages = int(pages_split[0].split('>')[-1])

for i in range(1,num_pages):
    url = 'https://suumo.jp/jj/common/ichiran/JJ901FC004/?initFlg=1&seniFlg=1&pc=30&ar=030&ra=030013&rnTmp=0005&newflg=0&km=1&rn=0005&rnek=000514970&pn={}'
    res = requests.get(url)
    soup = BeautifulSoup(res.text,'html.parser')
    bukkens = soup.find_all('li',attrs={'class':'cassette js-bukkenCassette'})

    for bukken in bukkens:
        bukken_info = bukken.select(".infodatabox-box-txt")
        # 沿線
        railline = bukken_info[1].text.split('/')[0]
    #     最寄駅
        station = bukken_info[1].text.split('/')[1]
        # 駅までの所要時間
        how_long = bukken_info[2].text
        how_long = int(re.sub(r"\D", "", how_long) )
        # 家賃
        rentprice = bukken.find('dd',attrs={'class':'infodatabox-details-txt'}).text
        rentprice = float(rentprice.replace('万円',''))
        # 占有面積
        price = bukken.find_all('dd',attrs={'class':'infodatabox-details-txt'})
        area = price[3].text
        area = float(re.sub(r"[^\d.]", "", area) )
        # 間取り
        room_type = price[4].text.replace('\r\n','').replace('\t','')

        datum = {}
        datum['沿線']=railline
        datum['最寄駅']=station
        datum['駅までの所要時間（分）']=how_long
        datum['家賃（万円）']=rentprice
        datum['占有面積']=area
        datum['間取り']=room_type
        data.append(datum)

# %%
import pandas as pd

# %%
df = pd.DataFrame(data)
df
# Out:
#           沿線   最寄駅  駅までの所要時間（分）  家賃（万円）     占有面積    間取り
# 0      東急池上線  戸越銀座            2     5.1  142.000  ワンルーム
# 1      ＪＲ山手線    目黒           11     5.5   15.252  ワンルーム
# 2      ＪＲ山手線    目黒           11     5.5   15.252  ワンルーム
# 3      東急目黒線   不動前            5     5.5   17.422  ワンルーム
# 4      ＪＲ山手線    目黒           11     5.5   15.252  ワンルーム
# ...      ...   ...          ...     ...      ...    ...
# 15895  ＪＲ山手線   五反田            4     7.2   18.920     1K
# 15896  ＪＲ山手線   五反田            4     7.2   18.920     1K
# 15897  ＪＲ山手線    目黒           14     7.2   19.572     1K
# 15898  都営三田線   白金台            7     7.2   19.572     1K
# 15899  都営三田線   白金台            7     7.2   19.572     1K
#
# [15900 rows x 6 columns]

# %%
df.columns
# Out:
# Index(['沿線', '最寄駅', '駅までの所要時間（分）', '家賃（万円）', '占有面積', '間取り'], dtype='object')

# %%
df.to_csv('suumo_gotanda.csv',index=None)
